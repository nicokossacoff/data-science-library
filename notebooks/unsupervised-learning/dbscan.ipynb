# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from unsupervised_helper_functions import *

# %%
df = pd.read_csv('data/banknote.txt', delimiter=' ')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Length    110 non-null    float64
#  1   Left      110 non-null    float64
#  2   Right     110 non-null    float64
#  3   Bottom    110 non-null    float64
#  4   Top       110 non-null    float64
#  5   Diagonal  110 non-null    float64
# dtypes: float64(6)
# memory usage: 5.3 KB

# %% [markdown]
# Antes de ajustar el modelo graficamos la distancia entre cada observación y su $k$ vecino más cercano. Con esto podemos encontrar el valor óptimo de $\varepsilon$ dado el valor de $MinPts$ elegido (en este caso, $MinPts=k$).

# %%
knn_displot(data=df, k=3, eps=0.9)

# %%
dbscan = DBSCAN(eps=.9, min_samples=3)
df['cluster'] = dbscan.fit_predict(df)

# %% [markdown]
# En el siguiente gráfico podemos observar los dos grupos (con las etiquetas $0$ y $1$). Al ruido le asignamos la etiqueta $-1$.

# %%
plot_clusters3d(df, labels=df['cluster'], title='DBSCAN Clustering of Banknote Data')
